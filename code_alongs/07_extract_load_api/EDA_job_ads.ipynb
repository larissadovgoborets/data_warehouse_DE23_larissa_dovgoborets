# %% [markdown]
# # EDA on jobtech API
#
# Arbetsförmedlingen API

# %%
import requests
import json

"""
Install python packages:
pip install -r requirements.txt

"""

url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"


def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))


def example_search_return_number_of_hits(query):
    # limit: 0 means no ads, just a value of how many ads were found.
    search_params = {'q': query, 'limit': 0}
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nNumber of hits = {number_of_hits}")


def example_search_loop_through_hits(query):
    # limit = 100 is the max number of hits that can be returned.
    # If there are more (which you find with ['total']['value'] in the json response)
    # you have to use offset and multiple requests to get all ads.
    search_params = {'q': query, 'limit': 100}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:
        print(f"{hit['headline']}, {hit['employer']['name']}")


if __name__ == '__main__':
    query = 'lärare uppsala'
    example_search_loop_through_hits(query)
    example_search_return_number_of_hits(query)
# Out:
# Lärare till resursenheten Pilskolan, Uppsala kommun
# Lärare i svenska och engelska till Palmbladsskolan, Uppsala kommun
# Lärare i svenska och SO till Björkvallsskolan (vikariat), Uppsala kommun
# Lärare i Svenska, STEAM Education holding AB
# Lärare i Svenska, STEAM Education holding AB
# Lärare i ryska till Försvarets tolkskola, Försvarsmakten
# Lärare i Idrott och hälsa, Statens Institutionsstyrelse
# Lärare fritidshem till Årstaskolan , Uppsala kommun
# Lärare i engelska, Lawrence Gelmon AB
# Lärare i Svenska, STEAM Education holding AB
# Lärare i Svenska, STEAM Education holding AB
# Lärare i Svenska, STEAM Education holding AB
# JENSEN grundskola Kåbo F-3 söker engagerad lärare i fritidshem, Jensen Education AB
# Lärare i årskurs 5 till Lindbackens skola, Uppsala kommun
# Förskolelärare/lärare till Östra Stenhagen anpassad grundskola, Uppsala kommun
# Lärare spanska, Raoul Wallenbergskolorna AB
# Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!, PersonalExpressen AB
# Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!, PersonalExpressen AB
# Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!, PersonalExpressen AB
# Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!, PersonalExpressen AB
# Förskollärare och lärare till olika skolformer, Clockwork Bemanning & Rekrytering AB
# Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!, PersonalExpressen AB
# Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!, PersonalExpressen AB
# Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!, PersonalExpressen AB
# Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!, PersonalExpressen AB
# Yrkesgymnasiet i Uppsala söker en frisörlärare, Thorengruppen AB
# Studie och yrkesvägledare till Yrkesgymnasiet, Thorengruppen AB
#
# Number of hits = 27

# %%
query = 'lärare uppsala'

params = {'q': query, 'limit': 100}

response =_get_ads(params)

response.keys()
# Out:
# dict_keys(['total', 'positions', 'query_time_in_millis', 'result_time_in_millis', 'stats', 'freetext_concepts', 'hits'])

# %%
response['total'], response['positions'], response['stats'], response['freetext_concepts']
# Out:
# ({'value': 27},
#  31,
#  [],
#  {'skill': [],
#   'occupation': ['lärare'],
#   'location': ['uppsala'],
#   'skill_must': [],
#   'occupation_must': [],
#   'location_must': [],
#   'skill_must_not': [],
#   'occupation_must_not': [],
#   'location_must_not': []})

# %%
response['hits']
# Out:
# [{'relevance': 1.0,
#   'id': '29039594',
#   'external_id': '46-212000-3005-36544',
#   'original_id': None,
#   'label': '[]',
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29039594',
#   'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/organisation/2120003005/logotyper/logo.png',
#   'headline': 'Lärare till resursenheten Pilskolan',
#   'application_deadline': '2024-09-01T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Resursenheten Pilskolan\r\n\r\nÄr du lärare med bred ämneskompetens? Vill du arbeta med elever med funktionsvariationer inom hörsel, språk och autism? Då kan det här vara jobbet för dig!\n\nPilskolan är en av Uppsala kommuns centrala resursenheter för elever med funktionsvariationer inom hörsel, språk och autism i årskurserna 1–6. Hos oss arbetar lärare och elevassistenter tillsammans med speciallärare, logoped, psykolog och teckenspråkstolk. All personal arbetar lågaffektivt och flera är kunniga inom tecken som stöd. Arbetet sker i små grupper och man arbetar nära varandra.\n\nHär kan du läsa mer om Pilskolan (https://resursenheter.uppsala.se/vara-resursenheter/pilskolan/)\n\nDitt uppdrag\nSom lärare i samtliga ämnen för grundskola 1-6 kommer du att planera och genomföra undervisning enligt läroplanen och delta i skolans utvecklingsarbete. Du förväntas bedriva en anpassad pedagogisk verksamhet utifrån behov och förutsättningar både individuellt och i liten grupp. I tjänsten ingår att samarbeta med övrig skolpersonal för att skapa en bra arbetsmiljö samt att bidra till att utveckla skolans lärmiljö tillsammans med elever och övrig personal.\n\nI uppdraget ingår även att:\n\n• dokumentera\n• arbeta med digitala hjälpmedel\n• bedöma elevernas förvärvade kunskaper\n• delta i möten med vårdnadshavare\n• delta i möten med andra aktörer exempelvis socialtjänsten, habiliteringen, barn och ungdomspsykiatrin.\n\n\n\nDin bakgrund\nVi söker dig som har svensk lärarlegitimation med behörighet att undervisa i årskurs 1-6. Har du speciallärarexamen ses det som meriterande. Vi ser att du har erfarenhet av arbete på grundskola. För att lyckas i arbetet behöver du ha erfarenhet av arbete i liten undervisningsgrupp eller av specialundervisning. Vi ser gärna att du har erfarenhet av arbete med barn med NPF diagnoser och/eller barn med hörselnedsättning. Det är även meriterande om du har erfarenhet av språkutvecklande arbetssätt och av arbete med bildstöd och sociala berättelser.\n\nArbetet kräver att du har god kännedom om skolans styrdokument samt grundskolans läroplan. Du behöver även ha goda muntliga och skriftliga kunskaper i svenska språket. Utöver detta behöver du ha bred ämneskompetens, goda kunskaper i Microsoft 365 samt goda dator- och systemkunskaper. Det är en fördel om du har kunskaper i konflikthantering.\n\nSom person är du pedagogisk och har förståelse för människors olika förutsättningar att ta till sig kunskap. Du tar initiativ och sätter igång aktiviteter för att uppnå resultat. Vidare är du bra på att skapa, underhålla och utveckla relationer. Sist men inte minst samarbetar och relaterar du till andra på ett lyhört och smidigt sätt.\n\nUpplysningar\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Barbro Överli, enhetschef, 018-727 60 01.\n\nFacklig företrädare: Sveriges lärare, Susanne Häll Lager, 073-423 56 38.\n\nHar du frågor gällande registrering av din ansökan, kontakta enheten för kompetensförsörjning: 018-727 68 24.\n\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\r\n\r\nOm vår organisation\nVälkommen till utbildningsförvaltningen. Vi erbjuder förskola, grundskola och gymnasieskola för barn och ungdomar mellan 0 och 20 år. Tillsammans jobbar vi mot målet att alla elever ska nå bästa möjliga kunskapsresultat.\n\nMer information om hur det är att arbeta i Uppsala kommun hittar du på Jobba hos oss - Uppsala kommun (https://www.uppsala.se/foretag-och-arbete/jobb-och-karriar/jobba-hos-oss/bli-en-av-oss/)\n\r\nVi undanber oss erbjudanden om annonserings- och rekryteringshjälp.\n\nDina personuppgifter kommer att användas för att administrera din ansökan inom Uppsala kommun.',
#    'text_formatted': 'Resursenheten Pilskolan\r\n\r\nÄr du lärare med bred ämneskompetens? Vill du arbeta med elever med funktionsvariationer inom hörsel, språk och autism? Då kan det här vara jobbet för dig!\n\nPilskolan är en av Uppsala kommuns centrala resursenheter för elever med funktionsvariationer inom hörsel, språk och autism i årskurserna 1–6. Hos oss arbetar lärare och elevassistenter tillsammans med speciallärare, logoped, psykolog och teckenspråkstolk. All personal arbetar lågaffektivt och flera är kunniga inom tecken som stöd. Arbetet sker i små grupper och man arbetar nära varandra.\n\nHär kan du läsa mer om Pilskolan (https://resursenheter.uppsala.se/vara-resursenheter/pilskolan/)\n\nDitt uppdrag\nSom lärare i samtliga ämnen för grundskola 1-6 kommer du att planera och genomföra undervisning enligt läroplanen och delta i skolans utvecklingsarbete. Du förväntas bedriva en anpassad pedagogisk verksamhet utifrån behov och förutsättningar både individuellt och i liten grupp. I tjänsten ingår att samarbeta med övrig skolpersonal för att skapa en bra arbetsmiljö samt att bidra till att utveckla skolans lärmiljö tillsammans med elever och övrig personal.\n\nI uppdraget ingår även att:\n\n• dokumentera\n• arbeta med digitala hjälpmedel\n• bedöma elevernas förvärvade kunskaper\n• delta i möten med vårdnadshavare\n• delta i möten med andra aktörer exempelvis socialtjänsten, habiliteringen, barn och ungdomspsykiatrin.\n\n\n\nDin bakgrund\nVi söker dig som har svensk lärarlegitimation med behörighet att undervisa i årskurs 1-6. Har du speciallärarexamen ses det som meriterande. Vi ser att du har erfarenhet av arbete på grundskola. För att lyckas i arbetet behöver du ha erfarenhet av arbete i liten undervisningsgrupp eller av specialundervisning. Vi ser gärna att du har erfarenhet av arbete med barn med NPF diagnoser och/eller barn med hörselnedsättning. Det är även meriterande om du har erfarenhet av språkutvecklande arbetssätt och av arbete med bildstöd och sociala berättelser.\n\nArbetet kräver att du har god kännedom om skolans styrdokument samt grundskolans läroplan. Du behöver även ha goda muntliga och skriftliga kunskaper i svenska språket. Utöver detta behöver du ha bred ämneskompetens, goda kunskaper i Microsoft 365 samt goda dator- och systemkunskaper. Det är en fördel om du har kunskaper i konflikthantering.\n\nSom person är du pedagogisk och har förståelse för människors olika förutsättningar att ta till sig kunskap. Du tar initiativ och sätter igång aktiviteter för att uppnå resultat. Vidare är du bra på att skapa, underhålla och utveckla relationer. Sist men inte minst samarbetar och relaterar du till andra på ett lyhört och smidigt sätt.\n\nUpplysningar\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Barbro Överli, enhetschef, 018-727 60 01.\n\nFacklig företrädare: Sveriges lärare, Susanne Häll Lager, 073-423 56 38.\n\nHar du frågor gällande registrering av din ansökan, kontakta enheten för kompetensförsörjning: 018-727 68 24.\n\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\r\n\r\nOm vår organisation\nVälkommen till utbildningsförvaltningen. Vi erbjuder förskola, grundskola och gymnasieskola för barn och ungdomar mellan 0 och 20 år. Tillsammans jobbar vi mot målet att alla elever ska nå bästa möjliga kunskapsresultat.\n\nMer information om hur det är att arbeta i Uppsala kommun hittar du på Jobba hos oss - Uppsala kommun (https://www.uppsala.se/foretag-och-arbete/jobb-och-karriar/jobba-hos-oss/bli-en-av-oss/)\n\r\nVi undanber oss erbjudanden om annonserings- och rekryteringshjälp.\n\nDina personuppgifter kommer att användas för att administrera din ansökan inom Uppsala kommun.',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': 'Tillsvidareanställning. 100%. \r\nTillträde enligt övernskommelse.'},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': 'Enligt överenskommelse',
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': None,
#    'organization_number': '2120003005',
#    'name': 'Uppsala kommun',
#    'workplace': 'Uppsala kommun'},
#   'application_details': {'information': None,
#    'reference': 'UBN-2024-04834',
#    'email': None,
#    'via_af': False,
#    'url': 'https://uppsala.powerinit.com/Modules/Recruitments/Public/?JobPositionId=36544&RefNo=UBN-2024-04834',
#    'other': None},
#   'experience_required': False,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'Nzmh_iTb_z7h',
#    'label': 'Grundlärare, 4-6',
#    'legacy_ams_taxonomy_id': '7653'},
#   'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#    'label': 'Grundskollärare',
#    'legacy_ams_taxonomy_id': '2341'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': None,
#    'postcode': None,
#    'city': None,
#    'coordinates': [17.638927, 59.858562]},
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2024-08-22T10:32:44',
#   'last_publication_date': '2024-09-01T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_PLATSBANKEN_DXA',
#   'timestamp': 1724315564611},
#  {'relevance': 1.0,
#   'id': '29032801',
#   'external_id': '46-212000-3005-36537',
#   'original_id': None,
#   'label': '[]',
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29032801',
#   'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/organisation/2120003005/logotyper/logo.png',
#   'headline': 'Lärare i svenska och engelska till Palmbladsskolan',
#   'application_deadline': '2024-08-30T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Palmbladsskolan\r\n\r\nÄr du lärare med behörighet att undervisa i svenska och engelska? Vill du arbeta på en skola där varje elev får möjlighet att växa utifrån egna förutsättningar? Hos oss får du bli en del av ett engagerat team där vi främjar kollegialt lärande. Varmt välkommen med din ansökan!\n\nPalmbladsskolan är en 6-9 skola med cirka 580 elever. som ligger i Årsta/Slavsta. Som lärare på Palmbladsskolan arbetar du nära dina kollegor dels i arbetslag och dels ämneslag. Skolans personal har en hög trivsel i medarbetarenkäter och det är låg personalomsättning. På Palmbladsskolan finns ett komplett elevhälsoteam och ett speciallärarteam som arbetar nära våra arbetslag. \n\nDitt uppdrag\nSom lärare i denna tjänst undervisar du i ämnena svenska och engelska. I din roll kommer du också att vara mentor för en grupp elever. Du får möjligheten att göra skillnad för våra elever genom att bidra med din kompetens, kunnande och ditt engagemang för att med eleven i centrum verka för att skolan når sina mål. Du planerar, genomför, utvärderar och utvecklar det pedagogiska arbetet enligt läroplan och övriga styrdokument.\n\nVi strävar efter ett kollegialt lärande där du i nära samarbete med dina kollegor utvecklar verksamheten. Tillsammans arbetar ni för att alla elever ska trivas och utvecklas utifrån sina individuella förutsättningar.\n\nDin bakgrund\nVi söker dig som som har lärarlegitimation alternativt inväntar legitimation för de årskurser och ämnen som avses. \nDet är meriterande om du har erfarenhet av arbete med språkutvecklande arbetssätt. För att lyckas i rollen behöver du ha god kännedom om skolans styrdokument samt grundskolans läroplan. Vi ser gärna att du har IT-kunskaper med inriktning mot pedagogiskt arbete. Arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska.\n\nSom person är du flexibel och kan se möjligheter i förändringar. Vidare tar du initiativ och sätter igång aktiviteter för att uppnå resultat. Sist men inte minst har du en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap.\n\nUpplysningar\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Ulrika Mattsson, rektor, 018-727 58 18. \n\nFacklig företrädare: Sveriges lärare, Tatjana Trivic, 018-727 64 67.\n\nHar du frågor gällande registrering av din ansökan, kontakta enheten för kompetensförsörjning: 018-727 68 24. \n\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\r\n\r\nOm vår organisation\nVälkommen till utbildningsförvaltningen. Vi erbjuder förskola, grundskola och gymnasieskola för barn och ungdomar mellan 0 och 20 år. Tillsammans jobbar vi mot målet att alla elever ska nå bästa möjliga kunskapsresultat.\n\nMer information om hur det är att arbeta i Uppsala kommun hittar du på Jobba hos oss - Uppsala kommun (https://www.uppsala.se/foretag-och-arbete/jobb-och-karriar/jobba-hos-oss/bli-en-av-oss/)\n\r\nVi undanber oss erbjudanden om annonserings- och rekryteringshjälp.\n\nDina personuppgifter kommer att användas för att administrera din ansökan inom Uppsala kommun.',
#    'text_formatted': 'Palmbladsskolan\r\n\r\nÄr du lärare med behörighet att undervisa i svenska och engelska? Vill du arbeta på en skola där varje elev får möjlighet att växa utifrån egna förutsättningar? Hos oss får du bli en del av ett engagerat team där vi främjar kollegialt lärande. Varmt välkommen med din ansökan!\n\nPalmbladsskolan är en 6-9 skola med cirka 580 elever. som ligger i Årsta/Slavsta. Som lärare på Palmbladsskolan arbetar du nära dina kollegor dels i arbetslag och dels ämneslag. Skolans personal har en hög trivsel i medarbetarenkäter och det är låg personalomsättning. På Palmbladsskolan finns ett komplett elevhälsoteam och ett speciallärarteam som arbetar nära våra arbetslag. \n\nDitt uppdrag\nSom lärare i denna tjänst undervisar du i ämnena svenska och engelska. I din roll kommer du också att vara mentor för en grupp elever. Du får möjligheten att göra skillnad för våra elever genom att bidra med din kompetens, kunnande och ditt engagemang för att med eleven i centrum verka för att skolan når sina mål. Du planerar, genomför, utvärderar och utvecklar det pedagogiska arbetet enligt läroplan och övriga styrdokument.\n\nVi strävar efter ett kollegialt lärande där du i nära samarbete med dina kollegor utvecklar verksamheten. Tillsammans arbetar ni för att alla elever ska trivas och utvecklas utifrån sina individuella förutsättningar.\n\nDin bakgrund\nVi söker dig som som har lärarlegitimation alternativt inväntar legitimation för de årskurser och ämnen som avses. \nDet är meriterande om du har erfarenhet av arbete med språkutvecklande arbetssätt. För att lyckas i rollen behöver du ha god kännedom om skolans styrdokument samt grundskolans läroplan. Vi ser gärna att du har IT-kunskaper med inriktning mot pedagogiskt arbete. Arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska.\n\nSom person är du flexibel och kan se möjligheter i förändringar. Vidare tar du initiativ och sätter igång aktiviteter för att uppnå resultat. Sist men inte minst har du en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap.\n\nUpplysningar\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Ulrika Mattsson, rektor, 018-727 58 18. \n\nFacklig företrädare: Sveriges lärare, Tatjana Trivic, 018-727 64 67.\n\nHar du frågor gällande registrering av din ansökan, kontakta enheten för kompetensförsörjning: 018-727 68 24. \n\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\r\n\r\nOm vår organisation\nVälkommen till utbildningsförvaltningen. Vi erbjuder förskola, grundskola och gymnasieskola för barn och ungdomar mellan 0 och 20 år. Tillsammans jobbar vi mot målet att alla elever ska nå bästa möjliga kunskapsresultat.\n\nMer information om hur det är att arbeta i Uppsala kommun hittar du på Jobba hos oss - Uppsala kommun (https://www.uppsala.se/foretag-och-arbete/jobb-och-karriar/jobba-hos-oss/bli-en-av-oss/)\n\r\nVi undanber oss erbjudanden om annonserings- och rekryteringshjälp.\n\nDina personuppgifter kommer att användas för att administrera din ansökan inom Uppsala kommun.',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': 'Tidsbegränsad anställning till och med 2024-12-20. 100%. \r\nTillträde snarast .'},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': 'Enligt överenskommelse',
#   'duration': {'concept_id': 'Xj7x_7yZ_jEn',
#    'label': '3 månader – upp till 6 månader',
#    'legacy_ams_taxonomy_id': '3'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': None,
#    'organization_number': '2120003005',
#    'name': 'Uppsala kommun',
#    'workplace': 'Uppsala kommun'},
#   'application_details': {'information': None,
#    'reference': 'UBN-2024-04781',
#    'email': None,
#    'via_af': False,
#    'url': 'https://uppsala.powerinit.com/Modules/Recruitments/Public/?JobPositionId=36537&RefNo=UBN-2024-04781',
#    'other': None},
#   'experience_required': False,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'iYgm_hfD_Bez',
#    'label': 'Ämneslärare, 7-9',
#    'legacy_ams_taxonomy_id': '7654'},
#   'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#    'label': 'Grundskollärare',
#    'legacy_ams_taxonomy_id': '2341'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': None,
#    'postcode': None,
#    'city': None,
#    'coordinates': [17.638927, 59.858562]},
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2024-08-20T10:19:43',
#   'last_publication_date': '2024-08-30T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_PLATSBANKEN_DXA',
#   'timestamp': 1724161683907},
#  {'relevance': 1.0,
#   'id': '29032143',
#   'external_id': '46-212000-3005-36538',
#   'original_id': None,
#   'label': '[]',
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29032143',
#   'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/organisation/2120003005/logotyper/logo.png',
#   'headline': 'Lärare i svenska och SO till Björkvallsskolan (vikariat)',
#   'application_deadline': '2024-08-27T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Björkvallsskolan\r\n\r\nVi söker just nu en engagerad lärare som vill vara med och forma framtidens stjärnor. Är du legitimerad lärare eller inväntar du ditt lärarlegitimation? Då kan du vara den vi söker! Hos oss får du möjlighet att utvecklas professionellt i en stimulerande och stödjande miljö, där eleverna alltid står i fokus. Varmt välkommen med din ansökan!\n\nBjörkvallsskolan är en trivsam skola från årskurs 6-9, nära naturen, belägen i Uppsala kommun, där målet är att alla elever ska lyckas. På vår skola känner sig eleverna trygga och får hjälp i skolarbetet av behöriga lärare. Eleverna möts av lärare som förväntar sig att eleverna når målen i alla ämnen, och vi arbetar aktivt för att varje elev ska känna motivation till skolarbete och lust att lära.\n\nVi ser att det är viktigt med en lugn studiemiljö för att möjliggöra för eleverna att tillgodogöra sig kunskaper och förmågor. Här uppmuntras våra elever till rörelse och fysiska aktiviteter och de har rörelsepass på schemat utöver idrotten varje vecka. På skolan finns ett komplett elevhälsoteam.\n\nBjörkvallsskolan bedriver ett aktivt värdegrundsarbete i syfte att skapa trygghet, ansvar och jämlikhet under elevernas hela skolgång, och arbetet involverar såväl pedagoger som elevhälsan. På vår skola är alla elever välkomna.\n\nHär kan du läsa mer om Björkvallsskolan (https://bjorkvallsskolan.uppsala.se/)\n\nDitt uppdrag\nSom lärare i denna tjänst undervisar du i ämnena SO och svenska. Du får möjligheten att göra skillnad för våra elever genom att bidra med din kompetens, kunnande och ditt engagemang för att med eleven i centrum verka för att skolan når sina mål. Du planerar, genomför, utvärderar och utvecklar det pedagogiska arbetet enligt läroplan och övriga styrdokument. I tjänsten kommer mentorsskap tillsammans med erfaren mentorskollega ingå.\n\nVi strävar efter ett kollegialt lärande där du i nära samarbete med dina kollegor utvecklar verksamheten. Tillsammans arbetar ni för att alla elever ska trivas och utvecklas utifrån sina individuella förutsättningar.\n\nDin bakgrund\nVi söker dig som har svenskt lärarlegitimation alternativt inväntar legitimation för de årskurser och ämnen som avses. Det är meriterande om du har erfarenhet av arbete med språkutvecklande arbetssätt. För att lyckas i rollen behöver du ha god kännedom om skolans styrdokument samt grundskolans läroplan. Vi se gärna att du har IT-kunskaper med inriktning mot pedagogiskt arbete. Arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska. \n\nSom person är du flexibel och kan se möjligheter i förändringar. Vidare tar du initiativ och sätter igång aktiviteter för att uppnå resultat. Sist men inte minst har du en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap.\n\nUpplysningar\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Johan Thalin, rektor, 018-727 78 81. \n\nFacklig företrädare: Sveriges lärare, Annicka Toll, 018-727 78 80. \n\nHar du frågor gällande registrering av din ansökan, kontakta enheten för kompetensförsörjning: 018-727 68 24. \n\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\r\n\r\nOm vår organisation\nVälkommen till utbildningsförvaltningen. Vi erbjuder förskola, grundskola och gymnasieskola för barn och ungdomar mellan 0 och 20 år. Tillsammans jobbar vi mot målet att alla elever ska nå bästa möjliga kunskapsresultat.\n\nMer information om hur det är att arbeta i Uppsala kommun hittar du på Jobba hos oss - Uppsala kommun (https://www.uppsala.se/foretag-och-arbete/jobb-och-karriar/jobba-hos-oss/bli-en-av-oss/)\n\r\nVi undanber oss erbjudanden om annonserings- och rekryteringshjälp.\n\nDina pers ...
#    'text_formatted': 'Björkvallsskolan\r\n\r\nVi söker just nu en engagerad lärare som vill vara med och forma framtidens stjärnor. Är du legitimerad lärare eller inväntar du ditt lärarlegitimation? Då kan du vara den vi söker! Hos oss får du möjlighet att utvecklas professionellt i en stimulerande och stödjande miljö, där eleverna alltid står i fokus. Varmt välkommen med din ansökan!\n\nBjörkvallsskolan är en trivsam skola från årskurs 6-9, nära naturen, belägen i Uppsala kommun, där målet är att alla elever ska lyckas. På vår skola känner sig eleverna trygga och får hjälp i skolarbetet av behöriga lärare. Eleverna möts av lärare som förväntar sig att eleverna når målen i alla ämnen, och vi arbetar aktivt för att varje elev ska känna motivation till skolarbete och lust att lära.\n\nVi ser att det är viktigt med en lugn studiemiljö för att möjliggöra för eleverna att tillgodogöra sig kunskaper och förmågor. Här uppmuntras våra elever till rörelse och fysiska aktiviteter och de har rörelsepass på schemat utöver idrotten varje vecka. På skolan finns ett komplett elevhälsoteam.\n\nBjörkvallsskolan bedriver ett aktivt värdegrundsarbete i syfte att skapa trygghet, ansvar och jämlikhet under elevernas hela skolgång, och arbetet involverar såväl pedagoger som elevhälsan. På vår skola är alla elever välkomna.\n\nHär kan du läsa mer om Björkvallsskolan (https://bjorkvallsskolan.uppsala.se/)\n\nDitt uppdrag\nSom lärare i denna tjänst undervisar du i ämnena SO och svenska. Du får möjligheten att göra skillnad för våra elever genom att bidra med din kompetens, kunnande och ditt engagemang för att med eleven i centrum verka för att skolan når sina mål. Du planerar, genomför, utvärderar och utvecklar det pedagogiska arbetet enligt läroplan och övriga styrdokument. I tjänsten kommer mentorsskap tillsammans med erfaren mentorskollega ingå.\n\nVi strävar efter ett kollegialt lärande där du i nära samarbete med dina kollegor utvecklar verksamheten. Tillsammans arbetar ni för att alla elever ska trivas och utvecklas utifrån sina individuella förutsättningar.\n\nDin bakgrund\nVi söker dig som har svenskt lärarlegitimation alternativt inväntar legitimation för de årskurser och ämnen som avses. Det är meriterande om du har erfarenhet av arbete med språkutvecklande arbetssätt. För att lyckas i rollen behöver du ha god kännedom om skolans styrdokument samt grundskolans läroplan. Vi se gärna att du har IT-kunskaper med inriktning mot pedagogiskt arbete. Arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska. \n\nSom person är du flexibel och kan se möjligheter i förändringar. Vidare tar du initiativ och sätter igång aktiviteter för att uppnå resultat. Sist men inte minst har du en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap.\n\nUpplysningar\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Johan Thalin, rektor, 018-727 78 81. \n\nFacklig företrädare: Sveriges lärare, Annicka Toll, 018-727 78 80. \n\nHar du frågor gällande registrering av din ansökan, kontakta enheten för kompetensförsörjning: 018-727 68 24. \n\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\r\n\r\nOm vår organisation\nVälkommen till utbildningsförvaltningen. Vi erbjuder förskola, grundskola och gymnasieskola för barn och ungdomar mellan 0 och 20 år. Tillsammans jobbar vi mot målet att alla elever ska nå bästa möjliga kunskapsresultat.\n\nMer information om hur det är att arbeta i Uppsala kommun hittar du på Jobba hos oss - Uppsala kommun (https://www.uppsala.se/foretag-och-arbete/jobb-och-karriar/jobba-hos-oss/bli-en-av-oss/)\n\r\nVi undanber oss erbjudanden om annonserings- och rekryteringshjälp.\n\nDina personupp ...
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': 'Tidsbegränsad anställning till och med 2024-12-20. 100%. \r\nTillträde 2024-09-02 eller enligt överenskommelse .'},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': 'Enligt överenskommelse',
#   'duration': {'concept_id': 'Xj7x_7yZ_jEn',
#    'label': '3 månader – upp till 6 månader',
#    'legacy_ams_taxonomy_id': '3'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': None,
#    'organization_number': '2120003005',
#    'name': 'Uppsala kommun',
#    'workplace': 'Uppsala kommun'},
#   'application_details': {'information': None,
#    'reference': 'UBN-2024-04791',
#    'email': None,
#    'via_af': False,
#    'url': 'https://uppsala.powerinit.com/Modules/Recruitments/Public/?JobPositionId=36538&RefNo=UBN-2024-04791',
#    'other': None},
#   'experience_required': False,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'iYgm_hfD_Bez',
#    'label': 'Ämneslärare, 7-9',
#    'legacy_ams_taxonomy_id': '7654'},
#   'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#    'label': 'Grundskollärare',
#    'legacy_ams_taxonomy_id': '2341'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': None,
#    'postcode': None,
#    'city': None,
#    'coordinates': [17.638927, 59.858562]},
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2024-08-20T08:27:03',
#   'last_publication_date': '2024-08-27T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_PLATSBANKEN_DXA',
#   'timestamp': 1724160654443},
#  {'relevance': 1.0,
#   'id': '29031211',
#   'external_id': '46-559169-3071-748587',
#   'original_id': None,
#   'label': '[]',
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29031211',
#   'logo_url': None,
#   'headline': 'Lärare i Svenska',
#   'application_deadline': '2024-08-31T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Uppsala International School (UIS) \xa0serves the needs of international families in the Uppsala Region and provides an exceptional international education in English and Swedish for students aged 6-19. We are currently enrolling students for the upcoming academic year 2024/2025 and warmly welcome your application.\n\nUIS follows the broad and balanced Cambridge International curriculum, delivering an International Education in English to students aged 6 to 19. Our education programme leads to IGCSE (at age 16) and A Level (at age 19) examinations.\n\n\n\nUppsala International School will offer The International Baccalaureate (IB) for students aged 16-19.  The IB programme has gained recognition and respect from the world’s leading universities. The programme is designed for highly motivated students looking for a rigourous educational experience.\n\nUppsala International School (UIS)  serves the needs of international families in the Uppsala Region and provides an exceptional international education for students aged 5-19. We are currently enrolling students for the upcoming academic year 2023/2024 and warmly welcome your application.\n\nWe follow the broad and balanced Cambridge International curriculum, delivering an International Education in English to students aged 5 to 19. Our education programme leads to IGCSE (at age 16) and A Level (at age 18) examinations.\n\n•\tUIS is a fully accredited Cambridge International School.\n\n•\tUppsala International School is a non-fee-paying school. \n\n\n\nOur campus at Palmbladsgatan 12, 754 50 Uppsala has a capacity to welcome up to 800 students. The campus provides ample space, high-quality facilities, and abundant resources necessary for students to develop and thrive on their educational journey.\n\n\n\nUIS prides itself on being an inclusive school that embraces diversity in terms of backgrounds, nationalities, and abilities. The multicultural mix of students creates a vibrant learning environment, and we set high standards for all our students, both inside and outside the classroom.\n\n\r\n\r\nWe are looking for an outstanding a highly motivated, creative, and dynamic Swedish teacher to join the https://uppsalainternationalschool.\r\n\r\ncom/\n\nQualifications\n\nThe successful applicant will have the following:\n\n - \xa0A bachelor’s degree in a related subject and a certified teaching qualification\xa0\n\nIf you meet the above criteria, are enthusiastic about teaching and learning and have the drive and passion to get the most from our students then we would very much welcome your application.\n\nImportant Note: \n\nhttps://uppsalainternationalschool.com/ is committed to safeguarding and promoting the welfare of all its students. Applicants will be required to submit a current police criminal clearance check or equivalent from their home country or current country of residence prior to appointment.',
#    'text_formatted': 'Uppsala International School (UIS) \xa0serves the needs of international families in the Uppsala Region and provides an exceptional international education in English and Swedish for students aged 6-19. We are currently enrolling students for the upcoming academic year 2024/2025 and warmly welcome your application.\n\nUIS follows the broad and balanced Cambridge International curriculum, delivering an International Education in English to students aged 6 to 19. Our education programme leads to IGCSE (at age 16) and A Level (at age 19) examinations.\n\n\n\nUppsala International School will offer The International Baccalaureate (IB) for students aged 16-19.  The IB programme has gained recognition and respect from the world’s leading universities. The programme is designed for highly motivated students looking for a rigourous educational experience.\n\nUppsala International School (UIS)  serves the needs of international families in the Uppsala Region and provides an exceptional international education for students aged 5-19. We are currently enrolling students for the upcoming academic year 2023/2024 and warmly welcome your application.\n\nWe follow the broad and balanced Cambridge International curriculum, delivering an International Education in English to students aged 5 to 19. Our education programme leads to IGCSE (at age 16) and A Level (at age 18) examinations.\n\n•\tUIS is a fully accredited Cambridge International School.\n\n•\tUppsala International School is a non-fee-paying school. \n\n\n\nOur campus at Palmbladsgatan 12, 754 50 Uppsala has a capacity to welcome up to 800 students. The campus provides ample space, high-quality facilities, and abundant resources necessary for students to develop and thrive on their educational journey.\n\n\n\nUIS prides itself on being an inclusive school that embraces diversity in terms of backgrounds, nationalities, and abilities. The multicultural mix of students creates a vibrant learning environment, and we set high standards for all our students, both inside and outside the classroom.\n\n\r\n\r\nWe are looking for an outstanding a highly motivated, creative, and dynamic Swedish teacher to join the https://uppsalainternationalschool.\r\n\r\ncom/\n\nQualifications\n\nThe successful applicant will have the following:\n\n - \xa0A bachelor’s degree in a related subject and a certified teaching qualification\xa0\n\nIf you meet the above criteria, are enthusiastic about teaching and learning and have the drive and passion to get the most from our students then we would very much welcome your application.\n\nImportant Note: \n\nhttps://uppsalainternationalschool.com/ is committed to safeguarding and promoting the welfare of all its students. Applicants will be required to submit a current police criminal clearance check or equivalent from their home country or current country of residence prior to appointment.\n\n\xa0',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': '100%. Tillträde: 2023-09-01\r\nTillsvidareanställning'},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': 'by agreement',
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': None,
#    'organization_number': '5591693071',
#    'name': 'STEAM Education holding AB',
#    'workplace': 'Uppsala International School'},
#   'application_details': {'information': None,
#    'reference': '2024/64',
#    'email': None,
#    'via_af': False,
#    'url': 'https://steam.varbi.com/what:job/jobID:748587/type:job/where:1/apply:1',
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'Nzmh_iTb_z7h',
#    'label': 'Grundlärare, 4-6',
#    'legacy_ams_taxonomy_id': '7653'},
#   'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#    'label': 'Grundskollärare',
#    'legacy_ams_taxonomy_id': '2341'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': None,
#    'postcode': None,
#    'city': None,
#    'coordinates': [17.638927, 59.858562]},
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [{'weight': 10,
#      'concept_id': 'Nzmh_iTb_z7h',
#      'label': 'Grundlärare, 4-6',
#      'legacy_ams_taxonomy_id': '7653'}],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2024-08-19T16:28:44',
#   'last_publication_date': '2024-08-31T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_PLATSBANKEN_DXA',
#   'timestamp': 1724077724583},
#  {'relevance': 1.0,
#   'id': '29031201',
#   'external_id': '46-559169-3071-748585',
#   'original_id': None,
#   'label': '[]',
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29031201',
#   'logo_url': None,
#   'headline': 'Lärare i Svenska',
#   'application_deadline': '2024-08-31T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Uppsala International School (UIS) \xa0serves the needs of international families in the Uppsala Region and provides an exceptional international education in English and Swedish for students aged 6-19. We are currently enrolling students for the upcoming academic year 2024/2025 and warmly welcome your application.\n\nUIS follows the broad and balanced Cambridge International curriculum, delivering an International Education in English to students aged 6 to 19. Our education programme leads to IGCSE (at age 16) and A Level (at age 19) examinations.\n\n\n\nUppsala International School will offer The International Baccalaureate (IB) for students aged 16-19.  The IB programme has gained recognition and respect from the world’s leading universities. The programme is designed for highly motivated students looking for a rigourous educational experience.\n\nUppsala International School (UIS)  serves the needs of international families in the Uppsala Region and provides an exceptional international education for students aged 5-19. We are currently enrolling students for the upcoming academic year 2023/2024 and warmly welcome your application.\n\nWe follow the broad and balanced Cambridge International curriculum, delivering an International Education in English to students aged 5 to 19. Our education programme leads to IGCSE (at age 16) and A Level (at age 18) examinations.\n\n•\tUIS is a fully accredited Cambridge International School.\n\n•\tUppsala International School is a non-fee-paying school. \n\n\n\nOur campus at Palmbladsgatan 12, 754 50 Uppsala has a capacity to welcome up to 800 students. The campus provides ample space, high-quality facilities, and abundant resources necessary for students to develop and thrive on their educational journey.\n\n\n\nUIS prides itself on being an inclusive school that embraces diversity in terms of backgrounds, nationalities, and abilities. The multicultural mix of students creates a vibrant learning environment, and we set high standards for all our students, both inside and outside the classroom.\n\n\r\n\r\nWe are looking for an outstanding a highly motivated, creative, and dynamic Swedish teacher to join the https://uppsalainternationalschool.\r\n\r\ncom/\n\nQualifications\n\nThe successful applicant will have the following:\n\n - \xa0A bachelor’s degree in a related subject and a certified teaching qualification\xa0\n\nIf you meet the above criteria, are enthusiastic about teaching and learning and have the drive and passion to get the most from our students then we would very much welcome your application.\n\nImportant Note: \n\nhttps://uppsalainternationalschool.com/ is committed to safeguarding and promoting the welfare of all its students. Applicants will be required to submit a current police criminal clearance check or equivalent from their home country or current country of residence prior to appointment.',
#    'text_formatted': 'Uppsala International School (UIS) \xa0serves the needs of international families in the Uppsala Region and provides an exceptional international education in English and Swedish for students aged 6-19. We are currently enrolling students for the upcoming academic year 2024/2025 and warmly welcome your application.\n\nUIS follows the broad and balanced Cambridge International curriculum, delivering an International Education in English to students aged 6 to 19. Our education programme leads to IGCSE (at age 16) and A Level (at age 19) examinations.\n\n\n\nUppsala International School will offer The International Baccalaureate (IB) for students aged 16-19.  The IB programme has gained recognition and respect from the world’s leading universities. The programme is designed for highly motivated students looking for a rigourous educational experience.\n\nUppsala International School (UIS)  serves the needs of international families in the Uppsala Region and provides an exceptional international education for students aged 5-19. We are currently enrolling students for the upcoming academic year 2023/2024 and warmly welcome your application.\n\nWe follow the broad and balanced Cambridge International curriculum, delivering an International Education in English to students aged 5 to 19. Our education programme leads to IGCSE (at age 16) and A Level (at age 18) examinations.\n\n•\tUIS is a fully accredited Cambridge International School.\n\n•\tUppsala International School is a non-fee-paying school. \n\n\n\nOur campus at Palmbladsgatan 12, 754 50 Uppsala has a capacity to welcome up to 800 students. The campus provides ample space, high-quality facilities, and abundant resources necessary for students to develop and thrive on their educational journey.\n\n\n\nUIS prides itself on being an inclusive school that embraces diversity in terms of backgrounds, nationalities, and abilities. The multicultural mix of students creates a vibrant learning environment, and we set high standards for all our students, both inside and outside the classroom.\n\n\r\n\r\nWe are looking for an outstanding a highly motivated, creative, and dynamic Swedish teacher to join the https://uppsalainternationalschool.\r\n\r\ncom/\n\nQualifications\n\nThe successful applicant will have the following:\n\n - \xa0A bachelor’s degree in a related subject and a certified teaching qualification\xa0\n\nIf you meet the above criteria, are enthusiastic about teaching and learning and have the drive and passion to get the most from our students then we would very much welcome your application.\n\nImportant Note: \n\nhttps://uppsalainternationalschool.com/ is committed to safeguarding and promoting the welfare of all its students. Applicants will be required to submit a current police criminal clearance check or equivalent from their home country or current country of residence prior to appointment.\n\n\xa0',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': '100%. Tillträde: 2023-09-01\r\nTillsvidareanställning'},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': 'by agreement',
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': None,
#    'organization_number': '5591693071',
#    'name': 'STEAM Education holding AB',
#    'workplace': 'Uppsala International School'},
#   'application_details': {'information': None,
#    'reference': '2024/63',
#    'email': None,
#    'via_af': False,
# ...
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2024-08-07T17:34:02',
#   'last_publication_date': '2024-09-06T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_ANNONSERA',
#   'timestamp': 1723044842406},
#  {'relevance': 1.0,
#   'id': '28967331',
#   'external_id': '46-556613-9290-743813',
#   'original_id': None,
#   'label': '[]',
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28967331',
#   'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/organisation/5566139290/logotyper/logo.png',
#   'headline': 'Yrkesgymnasiet i Uppsala söker en frisörlärare',
#   'application_deadline': '2024-08-30T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Hos oss på Yrkesgymnasiet får elever möjlighet att lära sig ett yrke från grunden på riktiga arbetsplatser med stöd av kunniga handledare och yrkeslärare. På Yrkesgymnasiet förläggs mer än hälften av utbildningstiden på en arbetsplats vilket skapar en stabil grund och en konkurrensfördel på arbetsmarknaden. Genom stöd från sina inspirerande handledare och engagerade pedagoger på skolan, rustas våra elever på bästa sätt inför det framtida arbetslivet.\n\n\r\n\r\nYrkesgymnasiet Uppsala söker i första hand en legitimerad yrkeslärare inom hantverksprogrammet / frisör, även du som har minst fem års arbetslivserfarenhet från frisörbranschen är välkommen att söka.\r\n\r\nHos oss får eleverna lära sig ett yrke från grunden på riktiga arbetsplatser med erfarna handledare. I denna tjänst får du möjlighet att dela med dig av dina kunskaper till framtidens frisörer. Mer än hälften av elevernas utbildningstid sker ute på en arbetsplats vilket ger dem en stabil grund och fördel på arbetsmarknaden. Våra elever förbereds på bästa möjliga sätt inför deras framtida yrkesliv med stöd av sina handledare och engagerade pedagoger.\n\nVi söker dig som:\n\n - Är legitimerad lärare inom frisör alternativt har minst fem års erfarenhet från frisörbranschen\xa0och en stark drivkraft att undervisa och handleda elever.\n - Är en utmärkt kommunikatör och lagspelare som kan verka som en brobyggare mellan skola, elever och näringsliv.\n - Har B-körkort och helst tillgång till egen bil.\n - Har en förmåga att både arbeta självständigt samtidigt som du är teamorienterad och tillsammans med kollegorna samarbetar för att på bästa sätt förbereda eleverna inför deras framtida yrkesliv.\n\nKvalifikationer\n\nLärarexamen alternativt gedigen erfarenhet inom frisörbranschen\xa0och en vilja att inspirera och utveckla nästa generation av unga frisörer. Lärarlegitimation och pedagogisk erfarenhet är önskvärt, men ej ett krav.\n\nOm du vill vara med och göra skillnad och ha en betydelsefull roll i framtidens medarbetare inom frisörbranschen,\xa0ansök idag!\n\n\xa0\n\n\xa0\n\nTill följd av skollagen ska utdrag ur polisens belastningsregister uppvisas vid anställning inom förskolan, förskoleklassen, fritidshemmet, grundskolan och gymnasiet. Vi uppmuntrar därför dig som söker att i direkt anslutning till att du skickar in din ansökan beställa ett utdrag från belastningsregistret. Blanketten för att beställa utdraget hittar du via polisen.se.',
#    'text_formatted': 'Hos oss på Yrkesgymnasiet får elever möjlighet att lära sig ett yrke från grunden på riktiga arbetsplatser med stöd av kunniga handledare och yrkeslärare. På Yrkesgymnasiet förläggs mer än hälften av utbildningstiden på en arbetsplats vilket skapar en stabil grund och en konkurrensfördel på arbetsmarknaden. Genom stöd från sina inspirerande handledare och engagerade pedagoger på skolan, rustas våra elever på bästa sätt inför det framtida arbetslivet.\n\n\r\n\r\nYrkesgymnasiet Uppsala söker i första hand en legitimerad yrkeslärare inom hantverksprogrammet / frisör, även du som har minst fem års arbetslivserfarenhet från frisörbranschen är välkommen att söka.\r\n\r\nHos oss får eleverna lära sig ett yrke från grunden på riktiga arbetsplatser med erfarna handledare. I denna tjänst får du möjlighet att dela med dig av dina kunskaper till framtidens frisörer. Mer än hälften av elevernas utbildningstid sker ute på en arbetsplats vilket ger dem en stabil grund och fördel på arbetsmarknaden. Våra elever förbereds på bästa möjliga sätt inför deras framtida yrkesliv med stöd av sina handledare och engagerade pedagoger.\n\nVi söker dig som:\n\n - Är legitimerad lärare inom frisör alternativt har minst fem års erfarenhet från frisörbranschen\xa0och en stark drivkraft att undervisa och handleda elever.\n - Är en utmärkt kommunikatör och lagspelare som kan verka som en brobyggare mellan skola, elever och näringsliv.\n - Har B-körkort och helst tillgång till egen bil.\n - Har en förmåga att både arbeta självständigt samtidigt som du är teamorienterad och tillsammans med kollegorna samarbetar för att på bästa sätt förbereda eleverna inför deras framtida yrkesliv.\n\nKvalifikationer\n\nLärarexamen alternativt gedigen erfarenhet inom frisörbranschen\xa0och en vilja att inspirera och utveckla nästa generation av unga frisörer. Lärarlegitimation och pedagogisk erfarenhet är önskvärt, men ej ett krav.\n\nOm du vill vara med och göra skillnad och ha en betydelsefull roll i framtidens medarbetare inom frisörbranschen,\xa0ansök idag!\n\n\xa0\n\n\xa0\n\nTill följd av skollagen ska utdrag ur polisens belastningsregister uppvisas vid anställning inom förskolan, förskoleklassen, fritidshemmet, grundskolan och gymnasiet. Vi uppmuntrar därför dig som söker att i direkt anslutning till att du skickar in din ansökan beställa ett utdrag från belastningsregistret. Blanketten för att beställa utdraget hittar du via polisen.se.',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': '80%. Tillträde: 2024-10-12 eller enligt annan överenskommelse\r\nTillsvidareanställning'},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': 'Månadslön ferietjänst',
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#    'label': 'Deltid',
#    'legacy_ams_taxonomy_id': '2'},
#   'scope_of_work': {'min': 80, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': None,
#    'organization_number': '5566139290',
#    'name': 'Thorengruppen AB',
#    'workplace': 'Yrkesgymnasiet, Uppsala'},
#   'application_details': {'information': None,
#    'reference': '2024/376',
#    'email': None,
#    'via_af': False,
#    'url': 'https://thorengruppen.varbi.com/what:job/jobID:743813/type:job/where:1/apply:1',
#    'other': None},
#   'experience_required': False,
#   'access_to_own_car': False,
#   'driving_license_required': True,
#   'driving_license': [{'concept_id': 'VTK8_WRx_GcM',
#     'label': 'B',
#     'legacy_ams_taxonomy_id': '3'}],
#   'occupation': {'concept_id': 'Hob8_zfc_5ge',
#    'label': 'Yrkeslärare',
#    'legacy_ams_taxonomy_id': '7128'},
#   'occupation_group': {'concept_id': '2x2V_UeL_6ke',
#    'label': 'Lärare i yrkesämnen',
#    'legacy_ams_taxonomy_id': '2320'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': None,
#    'postcode': None,
#    'city': None,
#    'coordinates': [17.638927, 59.858562]},
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [{'name': None,
#     'description': 'Carolina Klövstedt',
#     'email': None,
#     'telephone': '073-8213824',
#     'contact_type': None}],
#   'publication_date': '2024-07-13T08:14:16',
#   'last_publication_date': '2024-08-30T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_PLATSBANKEN_DXA',
#   'timestamp': 1720851256154},
#  {'relevance': 1.0,
#   'id': '28967297',
#   'external_id': '46-556613-9290-743812',
#   'original_id': None,
#   'label': '[]',
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/28967297',
#   'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/organisation/5566139290/logotyper/logo.png',
#   'headline': 'Studie och yrkesvägledare till Yrkesgymnasiet',
#   'application_deadline': '2024-08-31T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Hos oss på Yrkesgymnasiet får elever möjlighet att lära sig ett yrke från grunden på riktiga arbetsplatser med stöd av kunniga handledare och yrkeslärare. På Yrkesgymnasiet förläggs mer än hälften av utbildningstiden på en arbetsplats vilket skapar en stabil grund och en konkurrensfördel på arbetsmarknaden. Genom stöd från sina inspirerande handledare och engagerade pedagoger på skolan, rustas våra elever på bästa sätt inför det framtida arbetslivet.\n\n\r\n\r\nPå Yrkesgymnasiet strävar vi efter att ge våra elever bästa möjliga stöd i deras utbildningsval, yrkesmöjligheter och framtida arbetsmarknad.\r\n\r\nFör att uppnå detta söker vi nu en studie- och yrkesvägledare som brinner för att bidra till elevernas utveckling.\n\n\xa0\n\nVi söker dig som:\n\n - Kan ge individuell och gruppvägledning för att stimulera elevernas intresse och nyfikenhet inför framtida studier och yrkesval.\n - Har förmågan att arbeta självständigt och i team, och kan bygga nätverk med representanter från näringslivet och offentliga sektorn.\n - Är kommunikativ och motiverande i mötet med elever och lärare.\n - Har en stark drivkraft att, i samarbete med skolans elevhälsoteam (EHT), utveckla och forma vårt studie- och yrkesvägledningsprogram.\n - Arbetar utifrån och är väl förtrogen med de styrdokument som återfinns i Skolverkets lagar och styrdokument.\n\nKvalifikationer\n\nDu har studie- och yrkesvägledarexamen och det är meriterande om du har erfarenhet av att ha jobbat med vägledning tidigare.\n\nVill du vara med och göra skillnad och ha en betydelsefull roll i en organisation som ständigt utvecklas? Varmt välkommen in med din ansökan så att vi får tillfälle att berätta vad vi som arbetsgivare kan erbjuda.\n\n\n\n\n\nTill följd av skollagen ska utdrag ur polisens belastningsregister uppvisas vid anställning inom förskolan, förskoleklassen, fritidshemmet, grundskolan och gymnasiet. Vi uppmuntrar därför dig som söker att i direkt anslutning till att du skickar in din ansökan beställa ett utdrag från belastningsregistret. Blanketten för att beställa utdraget hittar du via polisen.se.',
#    'text_formatted': 'Hos oss på Yrkesgymnasiet får elever möjlighet att lära sig ett yrke från grunden på riktiga arbetsplatser med stöd av kunniga handledare och yrkeslärare. På Yrkesgymnasiet förläggs mer än hälften av utbildningstiden på en arbetsplats vilket skapar en stabil grund och en konkurrensfördel på arbetsmarknaden. Genom stöd från sina inspirerande handledare och engagerade pedagoger på skolan, rustas våra elever på bästa sätt inför det framtida arbetslivet.\n\n\r\n\r\nPå Yrkesgymnasiet strävar vi efter att ge våra elever bästa möjliga stöd i deras utbildningsval, yrkesmöjligheter och framtida arbetsmarknad.\r\n\r\nFör att uppnå detta söker vi nu en studie- och yrkesvägledare som brinner för att bidra till elevernas utveckling.\n\n\xa0\n\nVi söker dig som:\n\n - Kan ge individuell och gruppvägledning för att stimulera elevernas intresse och nyfikenhet inför framtida studier och yrkesval.\n - Har förmågan att arbeta självständigt och i team, och kan bygga nätverk med representanter från näringslivet och offentliga sektorn.\n - Är kommunikativ och motiverande i mötet med elever och lärare.\n - Har en stark drivkraft att, i samarbete med skolans elevhälsoteam (EHT), utveckla och forma vårt studie- och yrkesvägledningsprogram.\n - Arbetar utifrån och är väl förtrogen med de styrdokument som återfinns i Skolverkets lagar och styrdokument.\n\nKvalifikationer\n\nDu har studie- och yrkesvägledarexamen och det är meriterande om du har erfarenhet av att ha jobbat med vägledning tidigare.\n\nVill du vara med och göra skillnad och ha en betydelsefull roll i en organisation som ständigt utvecklas? Varmt välkommen in med din ansökan så att vi får tillfälle att berätta vad vi som arbetsgivare kan erbjuda.\n\n\n\n\n\nTill följd av skollagen ska utdrag ur polisens belastningsregister uppvisas vid anställning inom förskolan, förskoleklassen, fritidshemmet, grundskolan och gymnasiet. Vi uppmuntrar därför dig som söker att i direkt anslutning till att du skickar in din ansökan beställa ett utdrag från belastningsregistret. Blanketten för att beställa utdraget hittar du via polisen.se.',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': '20%. Tillträde: 2024-10-12 eller annan överenskommelse\r\nTillsvidareanställning'},
#   'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#    'label': 'Vanlig anställning',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': 'månadslön',
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#    'label': 'Deltid',
#    'legacy_ams_taxonomy_id': '2'},
#   'scope_of_work': {'min': 20, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': None,
#    'organization_number': '5566139290',
#    'name': 'Thorengruppen AB',
#    'workplace': 'Yrkesgymnasiet, Uppsala'},
#   'application_details': {'information': None,
#    'reference': '2024/375',
#    'email': None,
#    'via_af': False,
#    'url': 'https://thorengruppen.varbi.com/what:job/jobID:743812/type:job/where:1/apply:1',
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'KYPa_Jv8_ZbU',
#    'label': 'Studie- och yrkesvägledare',
#    'legacy_ams_taxonomy_id': '1253'},
#   'occupation_group': {'concept_id': 'jJF3_qaQ_Zsh',
#    'label': 'Studie- och yrkesvägledare',
#    'legacy_ams_taxonomy_id': '2352'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': None,
#    'postcode': None,
#    'city': None,
#    'coordinates': [17.638927, 59.858562]},
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [{'weight': 10,
#      'concept_id': 'KYPa_Jv8_ZbU',
#      'label': 'Studie- och yrkesvägledare',
#      'legacy_ams_taxonomy_id': '1253'}],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [{'name': None,
#     'description': 'Carolina Klövstedt',
#     'email': None,
#     'telephone': '073-8213824',
#     'contact_type': None}],
#   'publication_date': '2024-07-13T07:55:46',
#   'last_publication_date': '2024-08-31T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_PLATSBANKEN_DXA',
#   'timestamp': 1720850146987}]

# %%
response['hits'][0].keys()
# Out:
# dict_keys(['relevance', 'id', 'external_id', 'original_id', 'label', 'webpage_url', 'logo_url', 'headline', 'application_deadline', 'number_of_vacancies', 'description', 'employment_type', 'salary_type', 'salary_description', 'duration', 'working_hours_type', 'scope_of_work', 'access', 'employer', 'application_details', 'experience_required', 'access_to_own_car', 'driving_license_required', 'driving_license', 'occupation', 'occupation_group', 'occupation_field', 'workplace_address', 'must_have', 'nice_to_have', 'application_contacts', 'publication_date', 'last_publication_date', 'removed', 'removed_date', 'source_type', 'timestamp'])

# %%
response['hits'][0]['headline'], response['hits'][0]['employer']['name']
# Out:
# ('Lärare till resursenheten Pilskolan', 'Uppsala kommun')

# %%
query = 'data engineer'

params = {'q': query, 'limit': 100}

response =_get_ads(params)

response['total']
# Out:
# {'value': 67}

# %%
response['hits'][0]['headline'], response['hits'][0]['description']['text']
# Out:
# ('Data Engineer',
#  "We know it, you know it. Most companies ramble on about purpose and making the world a better place. And pretty often it feels a bit… well, forced. But we’d like to think that our story is special for real.\nOur founders, Shadi Bitar and Ninos Malki, came to Sweden from Syria when they were kids. Books became their compass, guiding them through the maze of life, and helping them shape their destinies in a new world.\nTheir dream was bold: What if they could unlock the world of books for everyone, making knowledge and inspiration accessible to all? Fast forward a few years, and the tale of Nextory was born.\nAt Nextory, we've crafted a revolutionary monthly subscription that empowers our users to devour books like never before, be it through reading or listening. It's not just a product; it's a passport to endless adventure and enlightenment.\nAnd now, we're on a quest to find a Data Engineer, someone as passionate as we are about making the world a happier place and enriching lives through the world of reading. Join our extraordinary team, and let's script a future where every day is a chapter of discovery, and every book is a key to a richer life.\nWHAT YOU WILL BE DOING\nAs a Data Engineer at Nextory you will work with keeping and developing the data drivenness of Nextory throughout the organization. With a curious, innovative and analytical mindset and tech-savvy approach you will fuel our data-driven teams.\nTogether with the team you will be responsible for data services which means, data warehousing, ML/AI, data quality and enabling data insights. You will build and run data pipelines, data warehouses, data frameworks and leverage ML/AI. We believe that you enjoy working autonomously in close collaboration with the cross-functional teams and other stakeholders.\nYou will be a part of an amazing team and be at the core of understanding a consumer subscription service - always with the continuous aspiration to increase reading! The position is based in Stockholm and you report to our COO.\n\n\nWho are you…\nWe believe that you are currently working in a similar role at a fast-moving company. We believe that you would like to develop a thorough understanding of how consumers use our service and be part of delivering key insights. By using various development techniques, you will keep us in the forefront of creating the best customer experience as well as providing a great self-service data platform. We believe that you take pride in structuring, integrating and transforming data on a daily basis - you believe that data quality is key!\nIf you have ambitions (or experience!) of working with areas like ML and AI we would love to give you a platform to show your practice! You thrive working in a dynamic and unpretentious environment where you take great responsibility for our product and your team!\n\n\nSKILLS AND QUALIFICATIONS\n• We believe you have, for the field, relevant educational background\n• We believe you have around 4 years of experience from working within the field\n• We believe you have experience from working with event-driven architecture (Kafka streams or similar)\n• We believe that you are an expert in SQL and have worked with Java, Python and/or similar languages\n• We believe that you have experience with cloud infrastructure (Azure, AWS, GCP) and cloud data warehousing, preferably BigQuery or equivalent\n• We believe that you have experience working with pipelines and data integration solutions with an ELT approach\n• We believe that you have experience in operating, maintaining and ensuring quality of production grade software\nWe are looking forward to your application which should include a CV or LinkedIn profile.")
